# %% [markdown]
# <a href="https://colab.research.google.com/github/mariewumeng/neuromancer_mw/blob/master/examples/ODEs/Part_2_param_estim_ODE_MW_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NeuroMANCER parameter estimation of an ODE system
#
# In this example we are concerned with a parameter estimation of white-box [ordinary differential equation](https://en.wikipedia.org/wiki/Ordinary_differential_equation) (ODE).
#
#
# ## System Identification Problem Setup
#
# <img src="https://github.com/mariewumeng/neuromancer_mw/blob/master/examples/figs/ODE.PNG?raw=1" width="400">
#
#  Starting from a given initial condition  $x_{0}$, the next state of the system  $x_{k+1}$
# is obtained by feeding the current state $x_{k}$ into the ODE model $N$, producing a derivative that is
# integrated using an integration scheme $\int$. In system identification, the loss $L$ is evaluated by comparing the  trajectory generated by the model with the training trajectory. The process can be repeated for multiple trajectories to improve the generalization of the model.
#
#
# ### References
#
# [1] Christian Legaard, Thomas Schranz, Gerald Schweiger, Ján Drgoňa, Basak Falay, Cláudio Gomes, Alexandros Iosifidis, Mahdi Abkar, and Peter Larsen. 2023. Constructing Neural Network Based Models for Simulating Dynamical Systems. ACM Comput. Surv. 55, 11, Article 236 (November 2023), 34 pages. https://doi.org/10.1145/3567591

# %% [markdown]
# ## NeuroMANCER and Dependencies

# %% [markdown]
# ### Install (Colab only)
# Skip this step when running locally.

# %%
# !pip install "neuromancer[examples] @ git+https://github.com/pnnl/neuromancer.git@master"

# !pip install "neuromancer[examples] @ git+https://github.com/mariewumeng/neuromancer_mw.git@master"
# Out:
# Collecting neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master
#   Cloning https://github.com/mariewumeng/neuromancer_mw.git (to revision master) to /tmp/pip-install-59bgoe2n/neuromancer_280bdff169614b9a8e6017318914538e
#   Running command git clone --filter=blob:none --quiet https://github.com/mariewumeng/neuromancer_mw.git /tmp/pip-install-59bgoe2n/neuromancer_280bdff169614b9a8e6017318914538e
#   Resolved https://github.com/mariewumeng/neuromancer_mw.git to commit 7e22b580a73f7c9b3491018aa0ed0581f96347ee
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dill (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.7.1)
# Collecting mlflow==2.5.0 (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading mlflow-2.5.0-py3-none-any.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 78.4 MB/s eta 0:00:00
# Collecting networkx==3.0.0 (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24.0 in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.5.3)
# Collecting plum-dispatch==1.7.3 (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading plum_dispatch-1.7.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.16.0)
# Requirement already satisfied: pydot==1.4.2 in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.4.2)
# Collecting pyts (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 46.2 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.1.0+cu118)
# Collecting torchdiffeq (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.10.2)
# Collecting casadi (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading casadi-3.6.3-cp310-none-manylinux2014_x86_64.whl (67.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.3.2)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.31.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (8.1.7)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.2.1)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.4)
# Collecting gitpython<4,>=2.1.0 (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 24.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.20.3)
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.31.0)
# Requirement already satisfied: packaging<24 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (23.2)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (6.8.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading alembic-1.12.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 27.1 MB/s eta 0:00:00
# Collecting docker<7,>=4.0.0 (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.2.5)
# Collecting querystring-parser<2 (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.0.22)
# Requirement already satisfied: pyarrow<13,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (9.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.5)
# Collecting gunicorn<21 (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.1.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot==1.4.2->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.2.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.2.3)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (67.7.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from pyts->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.56.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.1.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.9.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.6.4)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.1.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2.1.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->pyts->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.39.1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (0.1.7.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (3.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.5.0->neuromancer[examples]@ git+https://github.com/mariewumeng/neuromancer_mw.git@master)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: neuromancer
#   Building wheel for neuromancer (pyproject.toml) ... done
#   Created wheel for neuromancer: filename=neuromancer-1.4.1-py3-none-any.whl size=153450 sha256=a3fc0ab9d9904db3bcdb762cb8da68daccf875aa2531e24e257b31391f0259dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ifmakpt5/wheels/21/bf/8a/779a6aced4890beb44d4de0e13aacb539f64f21381c10b6587
# Successfully built neuromancer
# Installing collected packages: smmap, querystring-parser, plum-dispatch, networkx, Mako, gunicorn, dill, casadi, gitdb, docker, databricks-cli, alembic, torchdiffeq, pyts, gitpython, mlflow, neuromancer
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2
#     Uninstalling networkx-3.2:
#       Successfully uninstalled networkx-3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed Mako-1.2.4 alembic-1.12.1 casadi-3.6.3 databricks-cli-0.18.0 dill-0.3.7 docker-6.1.3 gitdb-4.0.11 gitpython-3.1.40 gunicorn-20.1.0 mlflow-2.5.0 networkx-3.0 neuromancer-1.4.1 plum-dispatch-1.7.3 pyts-0.13.0 querystring-parser-1.2.4 smmap-5.0.1 torchdiffeq-0.2.3

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import DataLoader
import os

from neuromancer.system import Node, System
from neuromancer.dynamics import integrators, ode
from neuromancer.dynamics.ode import ODESystem
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.loggers import BasicLogger
from neuromancer.dataset import DictDataset
from neuromancer.constraint import variable
from neuromancer.loss import PenaltyLoss
from neuromancer.psl import plot
from neuromancer import psl

torch.manual_seed(0)

# %% [markdown]
# ## Generate trajectories from ODE system to model
#
# Consider the [Brusselator system](https://en.wikipedia.org/wiki/Brusselator) defined by the following ODE:
#
# $$
#  \frac{dx_1}{dt} = \alpha + x_2 x_1^2 -\beta x_1 -x_1  \\
#  \frac{dx_2}{dt} = \beta x_1 - x_2 x_1^2
# $$

# %%
# %%  ground truth system
system = psl.systems['Brusselator1D']
# system = psl.systems['DoublePendulum']
ts = 0.05
modelSystem = system()
nx = modelSystem.nx
# simualte ground truth system
raw = modelSystem.simulate(nsim=1000, ts=ts)
# plot trajectories
plot.pltOL(Y=raw['Y'])
plot.pltPhase(X=raw['Y'])

# %% [markdown]
# ## Create training data of sampled trajectories
#
# We will obtain a dataset of sampled trajectories of the system dynamics to model:
# $$\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}], \, \, i \in [1, ..., m]$$
# where $N$ represents the prediction horizon, $m$ represents number of measured trajectories, and $i$ represents an index of the sampled trajectory.

# %%
def get_data(sys, nsim, nsteps, bs):
    """
    :param sys: (psl system)
    :param nsim: (int) Number of simulation steps of the true ODE model
    :param nsteps: (int) Number of prediction horizon timesteps
    :param bs: (int) batch size for minibatching

    """
    # simulate trajectories of a real system to generate the datasets
    train_sim, dev_sim, test_sim = [sys.simulate(nsim=nsim, ts=0.05) for i in range(3)]
    nx = sys.nx
    nbatch = nsim//nsteps
    length = (nsim//nsteps) * nsteps
    # training dataset
    trainX = train_sim['X'][:length].reshape(nbatch, nsteps, nx)
    trainX = torch.tensor(trainX, dtype=torch.float32)
    train_data = DictDataset({'X': trainX, 'xn': trainX[:, 0:1, :]}, name='train')
    train_loader = DataLoader(train_data, batch_size=bs,
                              collate_fn=train_data.collate_fn, shuffle=True)
    # development dataset
    devX = dev_sim['X'][:length].reshape(nbatch, nsteps, nx)
    devX = torch.tensor(devX, dtype=torch.float32)
    dev_data = DictDataset({'X': devX, 'xn': devX[:, 0:1, :]}, name='dev')
    dev_loader = DataLoader(dev_data, batch_size=bs,
                            collate_fn=dev_data.collate_fn, shuffle=True)
    # test dataset
    testX = test_sim['X'][:length].reshape(1, nsim, nx)
    testX = torch.tensor(testX, dtype=torch.float32)
    test_data = {'X': testX, 'xn': testX[:, 0:1, :]}

    return train_loader, dev_loader, test_data

# %%
nsim = 500   # number of simulation steps in the dataset
nsteps = 2   # number of prediction horizon steps in the loss function
bs = 32     # minibatching batch size
train_loader, dev_loader, test_data = get_data(modelSystem, nsim, nsteps, bs)

# %% [markdown]
# ## ODE system model in Neuromancer
#
# Here we construct a continuous-time ODE model  $\dot{x} = f_{\theta}(x)$ with trainable parameters $\theta$.

# %%
# define ODE system in Neuromancer
class BrusselatorParam(ODESystem):
    def __init__(self, insize=2, outsize=2):
        super().__init__(insize=insize, outsize=outsize)
        self.alpha = nn.Parameter(torch.tensor([5.0]), requires_grad=True)
        self.beta = nn.Parameter(torch.tensor([5.0]), requires_grad=True)

    def ode_equations(self, x):
        x1 = x[:, [0]]
        x2 = x[:, [-1]]
        dx1 = self.alpha + x2*x1**2 - self.beta*x1 - x1
        dx2 = self.beta*x1 - x2*x1**2
        return torch.cat([dx1, dx2], dim=-1)

# %% [markdown]
# Here we construct an open-loop system composed of the ODE models solved with ODE solver, e.g., [Runge–Kutta integrator](https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods):
# $x_{k+1} = \text{ODESolve}(f_{\theta}(x_k))$
#
# For training we need to obtain accurate reverse-mode gradients of the integrated ODE system. This can be done in two ways, either by unrolling the operations of the ODE solver and using the [backpropagation through time](https://en.wikipedia.org/wiki/Backpropagation_through_time) (BPTT) algorithm, or via [Adjoint state method](https://en.wikipedia.org/wiki/Adjoint_state_method).
#
# Neuromancer provides a set of ODE solvers implemented in [integrators.py](https://github.com/pnnl/neuromancer/blob/master/src/neuromancer/dynamics/integrators.py).
# For adjoint method we provide the interface to the [open-source implementation](https://github.com/rtqichen/torchdiffeq) via DiffEqIntegrator class. In this example we will use BPTT algorithm through unrolled RK4 solver.

# %%
# instantiate ODE system
brussels = BrusselatorParam()
# use ODE solver to discretize the ODE with a given timestep h
fxRK4 = integrators.RK4(brussels, h=ts)
# create symbolic system model in Neuromancer
dynamics_model = System([Node(fxRK4, ['xn'], ['xn'])], nsteps=nsteps)

# %%
# visualize the system
# dynamics_model.show()

# %% [markdown]
# ## Define system identification loss function terms
#
# Here we define loss function terms to fit the ODE parameters from given time-series data.
#
# **Tracking loss:**
# $$\ell_x = Q_x||x^i_k - \hat{x}^i_k||_2^2$$
# **Finite difference loss:**
# $$\ell_{dx} =  Q_{dx}||\Delta x^i_k - \Delta \hat{x}^i_k||_2^2$$
# where $\Delta x^i_k = x^i_{k+1} - x^i_k$

# %%
# %% Constraints + losses:
x = variable("X")
xhat = variable('xn')[:, :-1, :]

# define finite difference variables
xFD = (x[:, 1:, :] - x[:, :-1, :])
xhatFD = (xhat[:, 1:, :] - xhat[:, :-1, :])

# finite difference loss - i.e., fitting first derivatives
fd_loss = 2.0*((xFD == xhatFD)^2)
fd_loss.name = 'FD_loss'

# reference tracking loss
reference_loss = ((xhat == x)^2)
reference_loss.name = "ref_loss"

# %% [markdown]
# ## Construct System ID learning problem
#
# Given the training dataset $\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}]$ we want to solve the following problem:
#
# $$
# \begin{align}
# &\underset{\theta}{\text{minimize}}     && \sum_{i=1}^m \Big(\sum_{k=1}^{N}  Q_x||x^i_k - \hat{x}^i_k||_2^2  +  \sum_{k=1}^{N-1}  Q_{dx}||\Delta x^i_k - \Delta \hat{x}^i_k||_2^2  \Big) \\
# &\text{subject to}    && x^i_{k+1} =  \text{ODESolve}(f_{\theta}(x^i_k)) \\
# \end{align}
# $$

# %%
# %%
objectives = [reference_loss, fd_loss]
constraints = []
# create constrained optimization loss
loss = PenaltyLoss(objectives, constraints)
# construct constrained optimization problem
problem = Problem([dynamics_model], loss)

# %%
# plot computational graph
# problem.show()

# %% [markdown]
# ## Solve the problem
#
# We fit the unknown ODE parameters $\theta$ using stochastic gradient descent.

# %%
optimizer = torch.optim.Adam(problem.parameters(), lr=0.1)
# define trainer
trainer = Trainer(
    problem,
    train_loader,
    dev_loader,
    test_data,
    optimizer,
    patience=10,
    warmup=10,
    epochs=100,
    eval_metric="dev_loss",
    train_metric="train_loss",
    dev_metric="dev_loss",
    test_metric="dev_loss")

# %%
# %% train
best_model = trainer.train()
problem.load_state_dict(best_model)
# Out:
# epoch: 0  train_loss: 0.0288230013102293
# epoch: 1  train_loss: 0.017091521993279457
# epoch: 2  train_loss: 0.009261596947908401
# epoch: 3  train_loss: 0.004228680860251188
# epoch: 4  train_loss: 0.0015729435253888369
# epoch: 5  train_loss: 0.0003902610915247351
# epoch: 6  train_loss: 5.262921695248224e-05
# epoch: 7  train_loss: 5.848890396009665e-06
# epoch: 8  train_loss: 2.2836271455162205e-05
# epoch: 9  train_loss: 2.3258144210558385e-05
# epoch: 10  train_loss: 1.2638778571272269e-05
# epoch: 11  train_loss: 4.155470378464088e-06
# epoch: 12  train_loss: 5.376450644689612e-07
# epoch: 13  train_loss: 7.427908599311195e-08
# epoch: 14  train_loss: 2.137195451723528e-07
# epoch: 15  train_loss: 1.8988642125350452e-07
# epoch: 16  train_loss: 7.968330351104669e-08
# epoch: 17  train_loss: 1.4315766350136983e-08
# epoch: 18  train_loss: 2.349537897572418e-09
# epoch: 19  train_loss: 4.272514786407555e-09
# epoch: 20  train_loss: 4.045462187463045e-09
# epoch: 21  train_loss: 2.3972033247332547e-09
# epoch: 22  train_loss: 1.1583788372959702e-09
# epoch: 23  train_loss: 1.0416819629099905e-09
# epoch: 24  train_loss: 1.2027259188585049e-09
# epoch: 25  train_loss: 1.2549676853268465e-09
# epoch: 26  train_loss: 1.11034625938089e-09
# epoch: 27  train_loss: 1.130936455595588e-09
# epoch: 28  train_loss: 1.0464383803920896e-09
# epoch: 29  train_loss: 1.0884663170784847e-09
# epoch: 30  train_loss: 1.0948426609758144e-09
# epoch: 31  train_loss: 1.0395946326013927e-09
# epoch: 32  train_loss: 1.0723824050984376e-09
# epoch: 33  train_loss: 1.0496142843763323e-09
# epoch: 34  train_loss: 1.2104406366120202e-09
# Early stopping!!!
# <All keys matched successfully>

# %% [markdown]
# ## Parameter estimation results

# %%
# trained parameters
print('alpha = '+str(brussels.alpha.item()))
print('beta = '+str(brussels.beta.item()))
# Out:
# alpha = 1.0000513792037964
# beta = 2.999898672103882

# %%
# update the rollout length based on the test data
dynamics_model.nsteps = test_data['X'].shape[1]

# %%
# Test set results
test_outputs = dynamics_model(test_data)

pred_traj = test_outputs['xn'][:, :-1, :]
true_traj = test_data['X']
pred_traj = pred_traj.detach().numpy().reshape(-1, nx)
true_traj = true_traj.detach().numpy().reshape(-1, nx)
pred_traj, true_traj = pred_traj.transpose(1, 0), true_traj.transpose(1, 0)

# %%
# plot rollout
figsize = 25
fig, ax = plt.subplots(nx, figsize=(figsize, figsize))
labels = [f'$y_{k}$' for k in range(len(true_traj))]
for row, (t1, t2, label) in enumerate(zip(true_traj, pred_traj, labels)):
    if nx > 1:
        axe = ax[row]
    else:
        axe = ax
    axe.set_ylabel(label, rotation=0, labelpad=20, fontsize=figsize)
    axe.plot(t1, 'c', linewidth=4.0, label='True')
    axe.plot(t2, 'm--', linewidth=4.0, label='Pred')
    axe.tick_params(labelbottom=False, labelsize=figsize)
axe.tick_params(labelbottom=True, labelsize=figsize)
axe.legend(fontsize=figsize)
axe.set_xlabel('$time$', fontsize=figsize)
plt.tight_layout()
# plt.savefig('open_loop.png')
